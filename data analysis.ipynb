# %%
import pandas as pd

# %% [markdown]
# - avg_price 均價
# - short_amount 沽空額
# - short_pct 沽空比率
# - pe_ratio 市盈率
# - eps 每股盈利
# - earning_yield 收益率
# - dividend_ratio 派息比率
# - dividend_per_share 每股派息
# - nav_per_share 資產淨值
# - cap_flow 資金流向
# - volume_ratio 量比
# - rate_ratio 委比
# - turnover_rate 換手
# - volatility 振幅
# - avg_volume_90 3個月平均成交量
# - market_cap 市值

# %%
df = pd.read_csv('data/20230917.csv')
df
# Out:
#     Unnamed: 0  avg_price  short_amount  short_pct pe_ratio      eps  \
# 0           27     50.632    74400000.0    0.36644  deficit   -0.787
# 1           66     31.017    17800000.0    0.14002   19.497    1.590
# 2          101     10.506     4600000.0    0.04210   12.353    0.850
# 3          175      9.654    21200000.0    0.08009   16.756    0.575
# 4          241      4.663    33900000.0    0.28944  103.658    0.045
# 5          267      7.668     7720000.0    0.08069    2.954    2.590
# 6          288      4.115    12100000.0    0.09921    4.929    0.834
# 7          291     45.121    22400000.0    0.10023   29.934    1.512
# 8          316    104.567    35200000.0    0.34208    0.878  117.823
# 9          669     76.195    56800000.0    0.16479   16.613    4.596
# 10         823     37.668    31000000.0    0.08160    5.339    7.090
# 11         960     16.229    21900000.0    0.12183    3.511    4.603
# 12         981     20.366    49700000.0    0.03961   11.081    1.796
# ...
